# %% [markdown]
# # Data Ingestion
#
# **Purpose**:
#
# This notebook aims to conduct a lightweight data processing test using Python and SQL on an SQLite backend. We will adopt the medallion architecture, organising our data into Bronze, Silver, and Gold layers. Each layer will serve a specific purpose, beginning with the Bronze layer, which focuses on ingesting raw data.
#
# Our data source is KaggleHub, and the dataset used is GoodReadBooks. In addition to this dataset, we will generate synthetic data to fill in gaps such as member information, books borrowed, return times, and other relevant details.
#
# Finally, we will create views for the Gold layer to support refined and analytical use cases.

# %% [markdown]
# ## Import
# We begin by importing the necessary libraries and functions required for data ingestion and processing.

# %%
from src.data.dataset_utils import create_sqlite_dataset, download_dataset_from_kagglehub, generate_member, generate_borrowing_records
import pandas as pd

# %% [markdown]
# ## Dataset
#
# The dataset will be downloaded from KaggleHub (jealousleopard/goodreadsbooks) and stored in the .cache directory for subsequent access and processing.

# %%
path = download_dataset_from_kagglehub("jealousleopard/goodreadsbooks")
path
# Out:
# Path to dataset files: /home/anish/.cache/kagglehub/datasets/jealousleopard/goodreadsbooks/versions/2
# '/home/anish/.cache/kagglehub/datasets/jealousleopard/goodreadsbooks/versions/2'

# %% [markdown]
# ## SQLite dataset
# Next, we will create a database using the SQLite backend to store and manage the dataset for subsequent processing.

# %%
from src.data.dataset_utils import delete_sqlit_database
delete_sqlit_database("library.db") #we delete any exiting dataset called library.db for clean start
# Out:
# Database file does not exist.

# %%
conn, cursor = create_sqlite_dataset("library.db")

# %% [markdown]
# ## Bronze layer table
#
# Next, we will load the dataset. The GoodReadBooks dataset contains a books.csv file, which we will read using Pandas. This data will then be stored in our SQLite database as the bronze_books table, representing the raw data ingestion layer.

# %%
bronze_books = pd.read_csv(
    f"{path}/books.csv",
    on_bad_lines='skip',    
    quotechar='"',
    sep=","
)
display(bronze_books.sample(5))

bronze_books.to_sql("bronze_books", conn, if_exists="replace", index=False)
# Out:
#        bookID                                              title  \
# 5505    19911                                     Captive Dreams
# 10549   43015          A Long Way Gone: Memoirs of a Boy Soldier
# 3802    13632  Museum of Terror  Vol. 3: The Long Hair in the...
# 5368    19390                           Philosophical Dictionary
# 9942    40051                                            Evening
#
#                              authors  average_rating        isbn  \
# 5505   Angela Knight/Diane Whiteside            3.91  0425207757
# 10549                   Ishmael Beah            4.16  0374105235
# 3802                  Junji Ito/伊藤潤二            4.12  1593076398
# 5368     Voltaire/Theodore Besterman            4.09  014044257X
# 9942                     Susan Minot            3.37  0375700269
#
#               isbn13 language_code    num_pages  ratings_count  \
# 5505   9780425207758         en-US          336           1354
# 10549  9780374105235           eng          229         147820
# 3802   9781593076399           eng          392            628
# 5368   9780140442571         en-US          400           1394
# 9942   9780375700262           eng          288           3765
#
#        text_reviews_count publication_date             publisher
# 5505                   60         9/5/2006         Berkley Trade
# 10549                9547        2/13/2007  Sarah Crichton Books
# 3802                   26       11/21/2006      Dark Horse Manga
# 5368                   45        9/27/1979      Penguin Classics
# 9942                  550         9/7/1999               Vintage
# 11123

# %% [markdown]
# ## Silver Layer Table
#
# We will now create a cleaned version of the `bronze_books` table by performing the following tasks:
#
# 1. Create a `silver_books` table.
# 2. Filter out incomplete or invalid rows from the `bronze_books` table.
# 3. Remove any leading or trailing whitespace from book titles and author names.
# 4. Eliminate duplicate rows to ensure data consistency.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS silver_books AS
SELECT DISTINCT
    bookID AS BookID,
    TRIM(title) AS Title,
    TRIM(authors) AS Author,
    publication_date AS YearPublished,
    average_rating AS AvgRating
FROM bronze_books
WHERE title IS NOT NULL
  AND authors IS NOT NULL
  AND publication_date IS NOT NULL
  AND average_rating IS NOT NULL;
""")
conn.commit()

# %% [markdown]
# Let’s preview five sample rows from the silver_books table to verify the data cleaning process.

# %%
pd.read_sql_query("SELECT * FROM silver_books LIMIT 5;", conn)
# Out:
#    BookID                                              Title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author YearPublished  AvgRating
# 0  J.K. Rowling/Mary GrandPré     9/16/2006       4.57
# 1  J.K. Rowling/Mary GrandPré      9/1/2004       4.49
# 2                J.K. Rowling     11/1/2003       4.42
# 3  J.K. Rowling/Mary GrandPré      5/1/2004       4.56
# 4  J.K. Rowling/Mary GrandPré     9/13/2004       4.78

# %% [markdown]
# ### Synthetic Data Generation for Members
#
# We will now generate synthetic data to represent library members and their book borrowing behavior, as this information is not included in the original dataset.

# %% [markdown]
# #### Members table
# We will create a members table to store synthetic data representing individual library members, which will include relevant attributes such as member ID, name, and registration details.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Members (
    MemberID 
        INTEGER 
        PRIMARY KEY 
        AUTOINCREMENT,
    Name TEXT NOT NULL,
    JoinDate DATE DEFAULT (DATE('now'))
);
""")
conn.commit()

# %% [markdown]
# We will populate the `members` table with 50 synthetic entries to simulate a realistic set of library users.

# %%
members_list = generate_member(50)
members_list
# Out:
# [('Ivy Wilson', datetime.date(2024, 11, 11)),
#  ('John White', datetime.date(2024, 11, 23)),
#  ('Frank Thomas', datetime.date(2024, 12, 1)),
#  ('Diana Wilson', datetime.date(2025, 2, 22)),
#  ('Hassan Brown', datetime.date(2024, 9, 27)),
#  ('Diana Taylor', datetime.date(2024, 10, 6)),
#  ('Hassan Smith', datetime.date(2025, 4, 15)),
#  ('Diana White', datetime.date(2025, 1, 4)),
#  ('Alice Walker', datetime.date(2025, 3, 6)),
#  ('Charlie Walker', datetime.date(2024, 6, 17)),
#  ('Frank Smith', datetime.date(2024, 10, 3)),
#  ('Eve White', datetime.date(2024, 12, 22)),
#  ('Bob Roberts', datetime.date(2024, 10, 17)),
#  ('Frank Evans', datetime.date(2024, 10, 23)),
#  ('Grace Roberts', datetime.date(2024, 8, 18)),
#  ('Ivy Smith', datetime.date(2024, 8, 26)),
#  ('Hassan Walker', datetime.date(2025, 2, 1)),
#  ('Eve Wilson', datetime.date(2025, 2, 10)),
#  ('Eve Taylor', datetime.date(2024, 11, 14)),
#  ('Grace Roberts', datetime.date(2025, 2, 18)),
#  ('Hassan Evans', datetime.date(2025, 2, 28)),
#  ('Alice Walker', datetime.date(2025, 3, 6)),
#  ('Eve Walker', datetime.date(2024, 8, 28)),
#  ('John Walker', datetime.date(2025, 5, 2)),
#  ('Grace Jones', datetime.date(2025, 2, 17)),
#  ('Grace Evans', datetime.date(2024, 11, 2)),
#  ('Eve Walker', datetime.date(2025, 3, 2)),
#  ('John Walker', datetime.date(2024, 6, 9)),
#  ('Charlie White', datetime.date(2024, 6, 9)),
#  ('Bob Jones', datetime.date(2025, 4, 26)),
#  ('Ivy Smith', datetime.date(2024, 8, 30)),
#  ('Frank Thomas', datetime.date(2024, 10, 9)),
#  ('Diana White', datetime.date(2024, 11, 25)),
#  ('Diana Roberts', datetime.date(2024, 8, 14)),
#  ('Hassan Roberts', datetime.date(2025, 5, 6)),
#  ('Eve Brown', datetime.date(2025, 3, 14)),
#  ('Grace Walker', datetime.date(2025, 1, 31)),
#  ('Alice Roberts', datetime.date(2025, 4, 7)),
#  ('Charlie Wilson', datetime.date(2024, 7, 6)),
#  ('Diana Brown', datetime.date(2024, 7, 24)),
#  ('Grace Brown', datetime.date(2025, 2, 10)),
#  ('Alice White', datetime.date(2025, 2, 25)),
#  ('Hassan Walker', datetime.date(2025, 1, 25)),
#  ('Frank Roberts', datetime.date(2025, 3, 14)),
#  ('John Thomas', datetime.date(2025, 1, 28)),
#  ('Frank Thomas', datetime.date(2025, 5, 5)),
#  ('Alice Smith', datetime.date(2025, 2, 3)),
#  ('Bob Wilson', datetime.date(2025, 1, 23)),
#  ('Diana Wilson', datetime.date(2025, 3, 21)),
#  ('Bob White', datetime.date(2024, 9, 21))]

# %% [markdown]
# Next, we will insert the generated list into the members table.

# %%
cursor.executemany(
    "INSERT INTO Members (Name, JoinDate) VALUES (?, ?);",
    members_list
)
conn.commit()

pd.read_sql_query("SELECT * FROM Members;", conn)
# Out:
#     MemberID            Name    JoinDate
# 0          1      Ivy Wilson  2024-11-11
# 1          2      John White  2024-11-23
# 2          3    Frank Thomas  2024-12-01
# 3          4    Diana Wilson  2025-02-22
# 4          5    Hassan Brown  2024-09-27
# 5          6    Diana Taylor  2024-10-06
# 6          7    Hassan Smith  2025-04-15
# 7          8     Diana White  2025-01-04
# 8          9    Alice Walker  2025-03-06
# 9         10  Charlie Walker  2024-06-17
# 10        11     Frank Smith  2024-10-03
# 11        12       Eve White  2024-12-22
# 12        13     Bob Roberts  2024-10-17
# 13        14     Frank Evans  2024-10-23
# 14        15   Grace Roberts  2024-08-18
# 15        16       Ivy Smith  2024-08-26
# 16        17   Hassan Walker  2025-02-01
# 17        18      Eve Wilson  2025-02-10
# 18        19      Eve Taylor  2024-11-14
# 19        20   Grace Roberts  2025-02-18
# 20        21    Hassan Evans  2025-02-28
# 21        22    Alice Walker  2025-03-06
# 22        23      Eve Walker  2024-08-28
# 23        24     John Walker  2025-05-02
# 24        25     Grace Jones  2025-02-17
# 25        26     Grace Evans  2024-11-02
# 26        27      Eve Walker  2025-03-02
# 27        28     John Walker  2024-06-09
# 28        29   Charlie White  2024-06-09
# 29        30       Bob Jones  2025-04-26
# 30        31       Ivy Smith  2024-08-30
# 31        32    Frank Thomas  2024-10-09
# 32        33     Diana White  2024-11-25
# 33        34   Diana Roberts  2024-08-14
# 34        35  Hassan Roberts  2025-05-06
# 35        36       Eve Brown  2025-03-14
# 36        37    Grace Walker  2025-01-31
# 37        38   Alice Roberts  2025-04-07
# 38        39  Charlie Wilson  2024-07-06
# 39        40     Diana Brown  2024-07-24
# 40        41     Grace Brown  2025-02-10
# 41        42     Alice White  2025-02-25
# 42        43   Hassan Walker  2025-01-25
# 43        44   Frank Roberts  2025-03-14
# 44        45     John Thomas  2025-01-28
# 45        46    Frank Thomas  2025-05-05
# 46        47     Alice Smith  2025-02-03
# 47        48      Bob Wilson  2025-01-23
# 48        49    Diana Wilson  2025-03-21
# 49        50       Bob White  2024-09-21

# %% [markdown]
# ### Borrowing Records Table
#
# We will now create a `borrowing_records` table to capture synthetic borrowing activity. Each record will include the book ID, member ID, borrow date, and return date. A `NULL` value in the return date column will indicate that the book has not yet been returned.

# %%
book_ids = pd.read_sql_query("SELECT BookID FROM silver_books LIMIT 100;", conn)["BookID"].tolist()
member_ids = pd.read_sql_query("SELECT MemberID FROM Members;", conn)["MemberID"].tolist()

# %%
borrowing_records = generate_borrowing_records(book_ids, member_ids)
borrowing_records
# Out:
# [(5, 1, datetime.date(2025, 3, 26), datetime.date(2025, 4, 3)),
#  (4, 2, datetime.date(2025, 3, 14), datetime.date(2025, 4, 3)),
#  (135, 2, datetime.date(2025, 3, 30), datetime.date(2025, 4, 11)),
#  (129, 3, datetime.date(2025, 4, 11), datetime.date(2025, 4, 17)),
#  (45, 4, datetime.date(2025, 6, 1), None),
#  (140, 5, datetime.date(2025, 6, 2), datetime.date(2025, 6, 14)),
#  (137, 6, datetime.date(2025, 3, 24), datetime.date(2025, 4, 18)),
#  (16, 6, datetime.date(2025, 3, 25), None),
#  (106, 7, datetime.date(2025, 4, 23), datetime.date(2025, 5, 4)),
#  (154, 7, datetime.date(2025, 3, 13), None),
#  (105, 8, datetime.date(2025, 3, 27), datetime.date(2025, 4, 6)),
#  (85, 8, datetime.date(2025, 4, 1), None),
#  (27, 8, datetime.date(2025, 5, 28), None),
#  (31, 9, datetime.date(2025, 4, 2), datetime.date(2025, 4, 25)),
#  (4, 10, datetime.date(2025, 5, 9), None),
#  (86, 10, datetime.date(2025, 5, 23), None),
#  (8, 10, datetime.date(2025, 5, 12), datetime.date(2025, 5, 29)),
#  (122, 11, datetime.date(2025, 5, 3), None),
#  (139, 11, datetime.date(2025, 5, 19), datetime.date(2025, 6, 18)),
#  (66, 11, datetime.date(2025, 5, 25), datetime.date(2025, 6, 18)),
#  (51, 12, datetime.date(2025, 5, 10), datetime.date(2025, 5, 15)),
#  (142, 12, datetime.date(2025, 5, 3), None),
#  (10, 12, datetime.date(2025, 4, 27), datetime.date(2025, 5, 22)),
#  (78, 13, datetime.date(2025, 3, 24), datetime.date(2025, 4, 15)),
#  (153, 14, datetime.date(2025, 4, 4), datetime.date(2025, 4, 28)),
#  (31, 14, datetime.date(2025, 5, 9), datetime.date(2025, 6, 5)),
#  (119, 14, datetime.date(2025, 3, 21), None),
#  (162, 15, datetime.date(2025, 3, 24), datetime.date(2025, 4, 18)),
#  (26, 16, datetime.date(2025, 5, 26), datetime.date(2025, 6, 9)),
#  (140, 16, datetime.date(2025, 5, 6), None),
#  (91, 16, datetime.date(2025, 4, 5), datetime.date(2025, 4, 19)),
#  (89, 17, datetime.date(2025, 5, 18), None),
#  (152, 17, datetime.date(2025, 5, 9), datetime.date(2025, 5, 29)),
#  (76, 18, datetime.date(2025, 6, 4), datetime.date(2025, 6, 22)),
#  (22, 19, datetime.date(2025, 3, 22), datetime.date(2025, 4, 5)),
#  (5, 19, datetime.date(2025, 3, 17), datetime.date(2025, 3, 26)),
#  (157, 19, datetime.date(2025, 5, 8), datetime.date(2025, 6, 7)),
#  (162, 20, datetime.date(2025, 5, 14), datetime.date(2025, 6, 8)),
#  (16, 20, datetime.date(2025, 4, 19), None),
#  (86, 20, datetime.date(2025, 5, 3), None),
#  (26, 21, datetime.date(2025, 3, 20), datetime.date(2025, 4, 16)),
#  (30, 21, datetime.date(2025, 6, 4), datetime.date(2025, 6, 30)),
#  (45, 21, datetime.date(2025, 3, 29), None),
#  (21, 22, datetime.date(2025, 4, 9), None),
#  (57, 22, datetime.date(2025, 4, 27), datetime.date(2025, 5, 20)),
#  (79, 22, datetime.date(2025, 5, 1), datetime.date(2025, 5, 24)),
#  (100, 23, datetime.date(2025, 5, 15), datetime.date(2025, 6, 7)),
#  (72, 23, datetime.date(2025, 4, 6), datetime.date(2025, 4, 19)),
#  (86, 24, datetime.date(2025, 3, 16), datetime.date(2025, 4, 4)),
#  (66, 25, datetime.date(2025, 5, 31), datetime.date(2025, 6, 8)),
#  (151, 25, datetime.date(2025, 6, 3), None),
#  (129, 25, datetime.date(2025, 5, 3), datetime.date(2025, 5, 11)),
#  (119, 26, datetime.date(2025, 5, 28), datetime.date(2025, 6, 3)),
#  (96, 27, datetime.date(2025, 4, 18), datetime.date(2025, 4, 25)),
#  (67, 28, datetime.date(2025, 5, 19), datetime.date(2025, 6, 7)),
#  (85, 28, datetime.date(2025, 4, 7), datetime.date(2025, 4, 20)),
#  (140, 29, datetime.date(2025, 5, 5), datetime.date(2025, 5, 30)),
#  (109, 29, datetime.date(2025, 5, 26), datetime.date(2025, 6, 10)),
#  (91, 30, datetime.date(2025, 4, 6), datetime.date(2025, 4, 21)),
#  (81, 31, datetime.date(2025, 5, 21), None),
#  (86, 31, datetime.date(2025, 4, 29), datetime.date(2025, 5, 26)),
#  (63, 31, datetime.date(2025, 5, 25), datetime.date(2025, 6, 21)),
#  (135, 32, datetime.date(2025, 3, 24), datetime.date(2025, 4, 4)),
#  (119, 33, datetime.date(2025, 4, 13), None),
#  (12, 33, datetime.date(2025, 4, 5), None),
#  (77, 33, datetime.date(2025, 4, 3), datetime.date(2025, 4, 20)),
#  (86, 34, datetime.date(2025, 4, 2), datetime.date(2025, 4, 17)),
#  (14, 34, datetime.date(2025, 4, 2), datetime.date(2025, 4, 9)),
#  (142, 34, datetime.date(2025, 5, 31), None),
#  (142, 35, datetime.date(2025, 5, 16), datetime.date(2025, 6, 10)),
#  (61, 35, datetime.date(2025, 5, 6), datetime.date(2025, 5, 20)),
#  (106, 35, datetime.date(2025, 3, 22), datetime.date(2025, 4, 4)),
#  (142, 36, datetime.date(2025, 4, 3), datetime.date(2025, 4, 22)),
#  (157, 36, datetime.date(2025, 3, 31), datetime.date(2025, 4, 29)),
#  (85, 36, datetime.date(2025, 3, 15), datetime.date(2025, 4, 6)),
#  (151, 37, datetime.date(2025, 3, 14), datetime.date(2025, 4, 10)),
#  (93, 38, datetime.date(2025, 5, 2), datetime.date(2025, 5, 20)),
#  (90, 38, datetime.date(2025, 4, 29), None),
#  (2, 38, datetime.date(2025, 3, 23), datetime.date(2025, 4, 12)),
#  (131, 39, datetime.date(2025, 4, 3), datetime.date(2025, 4, 9)),
#  (9, 40, datetime.date(2025, 5, 4), datetime.date(2025, 6, 3)),
#  (155, 40, datetime.date(2025, 3, 17), datetime.date(2025, 4, 5)),
#  (85, 41, datetime.date(2025, 4, 15), datetime.date(2025, 4, 28)),
#  (94, 41, datetime.date(2025, 5, 1), datetime.date(2025, 5, 9)),
#  (76, 42, datetime.date(2025, 3, 19), None),
#  (74, 42, datetime.date(2025, 5, 13), datetime.date(2025, 6, 3)),
#  (63, 42, datetime.date(2025, 3, 13), datetime.date(2025, 4, 1)),
#  (51, 43, datetime.date(2025, 4, 13), None),
#  (10, 43, datetime.date(2025, 3, 14), None),
#  (66, 43, datetime.date(2025, 5, 11), datetime.date(2025, 5, 27)),
#  (4, 44, datetime.date(2025, 5, 10), None),
#  (67, 44, datetime.date(2025, 4, 12), datetime.date(2025, 5, 5)),
#  (76, 44, datetime.date(2025, 4, 2), datetime.date(2025, 4, 13)),
#  (29, 45, datetime.date(2025, 5, 7), datetime.date(2025, 5, 28)),
#  (153, 46, datetime.date(2025, 4, 16), None),
#  (93, 46, datetime.date(2025, 5, 6), None),
#  (57, 47, datetime.date(2025, 5, 5), datetime.date(2025, 5, 26)),
#  (74, 47, datetime.date(2025, 5, 28), datetime.date(2025, 6, 10)),
#  (153, 48, datetime.date(2025, 4, 12), datetime.date(2025, 5, 2)),
#  (77, 48, datetime.date(2025, 3, 17), datetime.date(2025, 4, 14)),
#  (2, 48, datetime.date(2025, 5, 17), None),
#  (27, 49, datetime.date(2025, 3, 15), None),
#  (139, 49, datetime.date(2025, 3, 31), datetime.date(2025, 4, 28)),
#  (37, 49, datetime.date(2025, 4, 9), None),
#  (9, 50, datetime.date(2025, 5, 7), datetime.date(2025, 5, 21)),
#  (119, 50, datetime.date(2025, 3, 14), datetime.date(2025, 4, 7))]

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS BorrowingRecords (
    RecordID 
        INTEGER 
        PRIMARY KEY 
        AUTOINCREMENT,
    BookID INTEGER,
    MemberID INTEGER,
    BorrowDate 
        DATE 
        DEFAULT (DATE('now')),
    ReturnDate DATE,
    FOREIGN KEY (BookID) 
        REFERENCES silver_books(BookID),
    FOREIGN KEY (MemberID) 
        REFERENCES Members(MemberID)
);
""")
conn.commit()

# %% [markdown]
# Next, we will insert the generated borrowing data into the borrowing_records table to complete our synthetic dataset.

# %%
cursor.executemany(
    """
    INSERT INTO BorrowingRecords (BookID, MemberID, BorrowDate, ReturnDate)
    VALUES (?, ?, ?, ?);
    """,
    borrowing_records
)
conn.commit()

# Preview
pd.read_sql_query("SELECT * FROM BorrowingRecords LIMIT 5;", conn)
# Out:
#    RecordID  BookID  MemberID  BorrowDate  ReturnDate
# 0         1       5         1  2025-03-26  2025-04-03
# 1         2       4         2  2025-03-14  2025-04-03
# 2         3     135         2  2025-03-30  2025-04-11
# 3         4     129         3  2025-04-11  2025-04-17
# 4         5      45         4  2025-06-01        None

# %% [markdown]
# ## Gold Layer View
#
# For the Gold layer, we will adopt a different approach by creating SQL views instead of physical tables. These views will include refined queries to support analytics and reporting use cases.

# %% [markdown]
# ### Top Rated Books View
#
# We will create a view to identify top-rated books. Any book with an average rating greater than 4.5, based on the `silver_books` table, will be included in this view.

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS gold_top_books AS
SELECT 
    Title, 
    Author, 
    YearPublished, 
    AvgRating
FROM silver_books
WHERE AvgRating >= 4.5
ORDER BY AvgRating DESC
LIMIT 20;
""")

conn.commit()

# %%
pd.read_sql_query("SELECT * FROM gold_top_books LIMIT 5;", conn)
# Out:
#                                                Title  \
# 0  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 1                  Willem de Kooning: Late Paintings
# 2  Literature Circle Guide: Bridge to Terabithia:...
# 3  Middlesex Borough (Images of America: New Jersey)
# 4  Zone of the Enders: The 2nd Runner Official St...
#
#                                  Author YearPublished  AvgRating
# 0   Aristophanes/F.W. Hall/W.M. Geldart     2/22/1922        5.0
# 1       Julie Sylvester/David Sylvester      9/1/2006        5.0
# 2                        Tara MacCarthy      1/1/2002        5.0
# 3  Middlesex Borough Heritage Committee     3/17/2003        5.0
# 4                            Tim Bogenn      3/6/2003        5.0

# %% [markdown]
# From the sample results, we can observe that several books have received a perfect 5.0 rating, indicating exceptional user feedback.

# %% [markdown]
# ### Top Borrowed Books View
#
# We will create a view named `gold_top_borrowed_books` to identify the most frequently borrowed books. This view will:
#
# * Join the `borrowing_records` table with the `silver_books` table using the `book_id` field.
# * Retrieve relevant metadata such as book title and author.
# * Group the data by `book_id`, count the total borrowings for each book, and order the results in descending order of borrow count.
# * Limit the output to the top 10 most borrowed books.

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS gold_top_borrowed_books AS
SELECT 
    book.Title, 
    book.Author, 
    COUNT(*) AS BorrowCount
FROM BorrowingRecords AS borrow
JOIN silver_books AS book 
    ON borrow.BookID = book.BookID
GROUP BY borrow.BookID
ORDER BY BorrowCount DESC
LIMIT 10;
""")
pd.read_sql_query("SELECT * FROM gold_top_borrowed_books;", conn)
# Out:
#                                                Title  \
# 0  The Heidi Chronicles: Uncommon Women and Other...
# 1         Ruby Ann's Down Home Trailer Park Cookbook
# 2  The Lord of the Rings: The Art of the Fellowsh...
# 3                               The Heidi Chronicles
# 4                                      Anna Karenina
# 5  eBay Business All-in-One Desk Reference for Du...
# 6                          Heirs of General Practice
# 7         The Changeling (Daughters of England  #15)
# 8  Harry Potter and the Chamber of Secrets (Harry...
# 9                                        Untouchable
#
#                                               Author  BorrowCount
# 0                                  Wendy Wasserstein            5
# 1                                    Ruby Ann Boxcar            4
# 2                                       Gary Russell            4
# 3                                  Wendy Wasserstein            4
# 4  Leo Tolstoy/Richard Pevear/Larissa Volokhonsky...            3
# 5                                     Marsha Collier            3
# 6                                        John McPhee            3
# 7                                      Philippa Carr            3
# 8                                       J.K. Rowling            3
# 9                        Mulk Raj Anand/E.M. Forster            2

# %% [markdown]
# ### Top Members by Number of Borrowings
#
# We will create a view to identify the top 10 members based on borrowing frequency. This will involve:
#
# * Joining the `borrowing_records` table with the `members` table using the `member_id` field.
# * Grouping the results by `member_id` and aggregating the total number of borrowings per member.
# * Ordering the results in descending order and limiting the output to the top 10 borrowers.

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS gold_top_members AS
SELECT 
     member.Name, 
     COUNT(*) AS TotalBorrows        
FROM BorrowingRecords AS borrow          
JOIN Members AS member 
     ON borrow.MemberID = member.MemberID                  
GROUP BY borrow.MemberID
ORDER BY TotalBorrows DESC               
LIMIT 10;
""")
pd.read_sql_query("SELECT * FROM gold_top_members;", conn)
# Out:
#              Name  TotalBorrows
# 0    Diana Wilson             3
# 1      Bob Wilson             3
# 2   Frank Roberts             3
# 3   Hassan Walker             3
# 4     Alice White             3
# 5   Alice Roberts             3
# 6       Eve Brown             3
# 7  Hassan Roberts             3
# 8   Diana Roberts             3
# 9     Diana White             3

# %% [markdown]
# ### Books Not Yet Returned
#
# We will create a view to list all books that have not yet been returned by members. In this view:
#
# * Only records with a `NULL` return date will be included.
# * We will calculate whether each book is overdue by checking if the borrow date exceeds 14 days from the current date.
# * The result will include relevant book and member details along with an `is_overdue` flag.

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS gold_unreturned_books AS
SELECT 
    member.Name AS Borrower,
    book.Title,
    borrow.BorrowDate,
    JULIANDAY('now') - JULIANDAY(borrow.BorrowDate) AS DaysOut,
    CASE 
        WHEN JULIANDAY('now') - JULIANDAY(borrow.BorrowDate) > 14 THEN 'Yes'
        ELSE 'No'
    END AS IsOverdue
FROM BorrowingRecords AS borrow
JOIN Members AS member 
    ON borrow.MemberID = member.MemberID
JOIN silver_books AS book 
    ON borrow.BookID = book.BookID
WHERE borrow.ReturnDate IS NULL;
""")
pd.read_sql_query("SELECT * FROM gold_unreturned_books;", conn)
# Out:
#           Borrower                                              Title  \
# 0     Diana Wilson  Agile Web Development with Rails: A Pragmatic ...
# 1     Diana Taylor  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 2     Hassan Smith             CliffsNotes on Tolstoy's Anna Karenina
# 3      Diana White                               The Heidi Chronicles
# 4      Diana White          Neither Here nor There: Travels in Europe
# 5   Charlie Walker  Harry Potter and the Chamber of Secrets (Harry...
# 6   Charlie Walker  The Heidi Chronicles: Uncommon Women and Other...
# 7      Frank Smith            The Power of One (The Power of One  #1)
# 8        Eve White         Ruby Ann's Down Home Trailer Park Cookbook
# 9      Frank Evans  The Lord of the Rings: The Art of the Fellowsh...
# 10       Ivy Smith  eBay Business All-in-One Desk Reference for Du...
# 11   Hassan Walker  Active Literacy Across the Curriculum: Strateg...
# 12   Grace Roberts  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 13   Grace Roberts  The Heidi Chronicles: Uncommon Women and Other...
# 14    Hassan Evans  Agile Web Development with Rails: A Pragmatic ...
# 15    Alice Walker               A Short History of Nearly Everything
# 16     Grace Jones                                      Anna Karenina
# 17       Ivy Smith                                 Giving Good Weight
# 18     Diana White  The Lord of the Rings: The Art of the Fellowsh...
# 19     Diana White  The Ultimate Hitchhiker's Guide: Five Complete...
# 20   Diana Roberts         Ruby Ann's Down Home Trailer Park Cookbook
# 21   Alice Roberts                    Simply Beautiful Beaded Jewelry
# 22     Alice White                          Heirs of General Practice
# 23   Hassan Walker  Hatchet: A Guide for Using "Hatchet" in the Cl...
# 24   Hassan Walker       Harry Potter Collection (Harry Potter  #1-6)
# 25   Frank Roberts  Harry Potter and the Chamber of Secrets (Harry...
# 26    Frank Thomas                                      Anna Karenina
# 27    Frank Thomas                                Heidi (Heidi  #1-2)
# 28      Bob Wilson  Harry Potter and the Order of the Phoenix (Har...
# 29    Diana Wilson          Neither Here nor There: Travels in Europe
# 30    Diana Wilson   The Lord of the Rings: Complete Visual Companion
#
#     BorrowDate    DaysOut IsOverdue
# 0   2025-06-01   8.344508        No
# 1   2025-03-25  76.344508       Yes
# 2   2025-03-13  88.344508       Yes
# 3   2025-04-01  69.344508       Yes
# 4   2025-05-28  12.344508        No
# 5   2025-05-09  31.344508       Yes
# 6   2025-05-23  17.344508       Yes
# 7   2025-05-03  37.344508       Yes
# 8   2025-05-03  37.344508       Yes
# 9   2025-03-21  80.344508       Yes
# 10  2025-05-06  34.344508       Yes
# 11  2025-05-18  22.344508       Yes
# 12  2025-04-19  51.344508       Yes
# 13  2025-05-03  37.344508       Yes
# 14  2025-03-29  72.344508       Yes
# 15  2025-04-09  61.344508       Yes
# 16  2025-06-03   6.344508        No
# 17  2025-05-21  19.344508       Yes
# 18  2025-04-13  57.344508       Yes
# 19  2025-04-05  65.344508       Yes
# 20  2025-05-31   9.344508        No
# 21  2025-04-29  41.344508       Yes
# 22  2025-03-19  82.344508       Yes
# 23  2025-04-13  57.344508       Yes
# 24  2025-03-14  87.344508       Yes
# 25  2025-05-10  30.344508       Yes
# 26  2025-04-16  54.344508       Yes
# 27  2025-05-06  34.344508       Yes
# 28  2025-05-17  23.344508       Yes
# 29  2025-03-15  86.344508       Yes
# 30  2025-04-09  61.344508       Yes

# %% [markdown]
# ### Month-by-Month Borrowing Activity
#
# We will create a view to analyse borrowing trends over time by aggregating the number of books borrowed each month. This will help us observe borrowing patterns and seasonal activity.

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS gold_monthly_borrowing AS
SELECT 
    strftime('%Y-%m', BorrowDate) AS Month,
    COUNT(*) AS BorrowCount
FROM BorrowingRecords
GROUP BY Month
ORDER BY Month ASC;
""")
pd.read_sql_query("SELECT * FROM gold_monthly_borrowing;", conn)
# Out:
#      Month  BorrowCount
# 0  2025-03           29
# 1  2025-04           30
# 2  2025-05           42
# 3  2025-06            5

# %% [markdown]
# ## Data Pipeline
#
# Now that the data structure and transformations are validated, we will create a data ingestion pipeline to automate the population of all three layers—Bronze, Silver, and Gold.

# %%
from src.etl.bronze_etl import BronzeETL
from src.etl.silver_etl import SilverETL
from src.etl.gold_etl import GoldETL

def run_bronze_etl():
    bronze = BronzeETL()
    bronze.download_data()
    bronze.load_raw_books()
    bronze.write_to_sqlite()

def run_silver_etl():
    silver = SilverETL()
    silver.transform_bronze_books()
    silver.create_members_table(total_members=20)
    silver.create_borrowing_records_table()
    silver.preview_tables()

def run_gold_etl():
    gold = GoldETL()
    gold.create_top_books_table()
    gold.create_top_borrowed_books_view()
    gold.create_unreturned_books_view()
    gold.create_monthly_borrowing_view()
    gold.preview_gold_outputs()

def main():
    print("Running Bronze ETL...")
    run_bronze_etl()

    print("\nRunning Silver ETL...")
    run_silver_etl()

    print("\nRunning Gold ETL...")
    run_gold_etl()


# main()
